# %% [markdown]
# # Julia 深度學習：可微分程式設計
#
# ## 作業 031：對神經網路層微分
#
# 請自行撰寫一個型別，型別代表神經網路的一層運算，並且對它微分。神經網路層的一般式如下：
#
# $$
# y = \sigma (Wx + b)
# $$
#
# 其中 `W` 為參數矩陣，`b` 為參數向量，`x` 為輸入向量，`y` 為輸出向量。要取得向量的微分值，需要將向量縮減為純量，如下：
#
# ```
# gradient(x -> sum(y), 1)
# ```

# %%
using Zygote

# %%
import Base: +, -

struct Point
  x::Float64
  y::Float64
end

# %%
(a::Point, b::Point) = Point(a.x + b.x, a.y + b.y)
# Out:
# syntax: type declarations on global variables are not yet supported
#
# Stacktrace:
#  [1] top-level scope at C:\Users\Administrator\.julia\packages\IJulia\DrVMH\src\kernel.jl:52

# %%
a = Point(1, 2)
b = Point(3, 4)
# Out:
# Point(3.0, 4.0)

# %%
gradient(y->(y+b).x, a)
# Out:
# MethodError: no method matching +(::Point, ::Point)
# Closest candidates are:
#   +(::Any, ::Any, !Matched::Any, !Matched::Any...) at operators.jl:529
#   +(!Matched::ChainRulesCore.DoesNotExist, ::Any) at C:\Users\Administrator\.julia\packages\ChainRulesCore\Q5Nrj\src\differential_arithmetic.jl:20
#   +(!Matched::ChainRulesCore.One, ::Any) at C:\Users\Administrator\.julia\packages\ChainRulesCore\Q5Nrj\src\differential_arithmetic.jl:64
#   ...
#
# Stacktrace:
#  [1] macro expansion at C:\Users\Administrator\.julia\packages\Zygote\z3bQd\src\compiler\interface2.jl:0 [inlined]
#  [2] _pullback(::Zygote.Context, ::typeof(+), ::Point, ::Point) at C:\Users\Administrator\.julia\packages\Zygote\z3bQd\src\compiler\interface2.jl:13
#  [3] #3 at .\In[9]:1 [inlined]
#  [4] _pullback(::Zygote.Context, ::getfield(Main, Symbol("##3#4")), ::Point) at C:\Users\Administrator\.julia\packages\Zygote\z3bQd\src\compiler\interface2.jl:0
#  [5] _pullback(::Function, ::Point) at C:\Users\Administrator\.julia\packages\Zygote\z3bQd\src\compiler\interface.jl:38
#  [6] pullback(::Function, ::Point) at C:\Users\Administrator\.julia\packages\Zygote\z3bQd\src\compiler\interface.jl:44
#  [7] gradient(::Function, ::Point) at C:\Users\Administrator\.julia\packages\Zygote\z3bQd\src\compiler\interface.jl:53
#  [8] top-level scope at In[9]:1
