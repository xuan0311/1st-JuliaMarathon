# %% [markdown]
# # Julia 深度學習：可微分程式設計
#
# ## 作業 031：對神經網路層微分
#
# 請自行撰寫一個型別，型別代表神經網路的一層運算，並且對它微分。神經網路層的一般式如下：
#
# $$
# y = \sigma (Wx + b)
# $$
#
# 其中 `W` 為參數矩陣，`b` 為參數向量，`x` 為輸入向量，`y` 為輸出向量。要取得向量的微分值，需要將向量縮減為純量，如下：
#
# ```
# gradient(x -> sum(y), 1)
# ```

# %%
using Zygote

# %%
mutable struct Layer
    W::Matrix
    b::Vector
end

# %%
(l::Layer)(x) = identity(l.W*x + l.b)

# %%
l = Layer(rand(3, 4), rand(3))
# Out:
# Layer([0.5618628769417575 0.8202718802646698 0.8312844360938463 0.8845948344318044; 0.36578732050349494 0.5261314178273666 0.6367144911141758 0.8819095541572619; 0.4001486108977452 0.46190647330053936 0.5283088515270387 0.2214975671997952], [0.8081314734818477, 0.48341594728093806, 0.3234931444712812])

# %%
gradient(x -> sum(l(x)), rand(4))
# Out:
# ([1.3277988083429977, 1.8083097713925758, 1.9963077787350607, 1.9880019557888615],)
