# %% [markdown]
# # Julia 數值系統介紹
#
# ## Day 004 作業
#
# 今天的內容提到整數及浮點數型別之最小值和最大值：
#
# |是否有正負號|型別|<div style="width:120px">最大值</div>|<div style="width:120px">最小值</div>|
# |---|---|---|---|
# |有|Int128, Int64, Int32, Int16, Int8|$2^{位元數-1}-1$|$-2^{位元數-1}$|
# |無|UInt128, UInt64, UInt32, UInt16, UInt8|$2^{位元數}-1$|$0$|
#
# |型別|最小值|最大值|
# |---|---|---|
# |`Float64`|-Inf|Inf|
# |`Float32`|-Inf 或 -Inf32|Inf 或 Inf32|
# |`Float16`|-Inf 或 -Inf16|Inf 或 Inf16|
#
# ### 作業：範例程式示範了 Int64 及 Float64 的最小值和最大值，作業請列出並觀察其他整數及浮點數型別的最小值和最大值。

# %% [markdown]
# 呼叫 `typemin()` 及 `typemax()` 函式得到各型別的最小值和最大值。
#
# 列出 Int128, Int32, Int16, Int8, UInt128, UInt64, UInt32, UInt16, UInt8 整數型別的最小值及最大值

# %%
types = [Int128, Int32, Int16, Int8, UInt128, UInt64, UInt32, UInt16, UInt8]
for t in types
    println("$(rpad(t,7)): value_min= $(typemin(t)), value_max= $(typemax(t))")
end
# Out:
# Int128 : value_min= -170141183460469231731687303715884105728, value_max= 170141183460469231731687303715884105727
# Int32  : value_min= -2147483648, value_max= 2147483647
# Int16  : value_min= -32768, value_max= 32767
# Int8   : value_min= -128, value_max= 127
# UInt128: value_min= 0, value_max= 340282366920938463463374607431768211455
# UInt64 : value_min= 0, value_max= 18446744073709551615
# UInt32 : value_min= 0, value_max= 4294967295
# UInt16 : value_min= 0, value_max= 65535
# UInt8  : value_min= 0, value_max= 255

# %% [markdown]
# 列出 Float32, Float16 浮點數型別的最小和最大值

# %%
println("$(rpad(Float32,7)): value_min= $(typemin(Float32)), value_max= $(typemax(Float32))")
println("$(rpad(Float16,7)): value_min= $(typemin(Float16)), value_max= $(typemax(Float16))")
# Out:
# Float32: value_min= -Inf, value_max= Inf
# Float16: value_min= -Inf, value_max= Inf
